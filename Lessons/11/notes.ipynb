# %% [markdown]
# # Funkcje 2/2

# %% [markdown]
# ## Type hinting, czyli podpowiadanie typów

# %%
def prostokat(a: float, b: float):
    obwod = 2*a + 2*b
    return obwod

# %%
# Miejsce na testy
wynik = prostokat(10, 20)
wynik += 10
print(wynik)
# Out:
# 70

# %%
def prostokat(a: float, b: float) -> float:
    obwod = 2*a + 2*b
    return obwod

# %%
# Miejsce na testy
wynik = prostokat(5, 6)
