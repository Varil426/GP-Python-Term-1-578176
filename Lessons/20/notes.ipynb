# %% [markdown]
# # Wstęp do programowania obiektowego
#
# ## Klasy

# %%
class Uczen:
    imie = ""
    nazwisko = ""
    wiek = 0
    oceny = []

    def info(self):
        return f"{self.imie} {self.nazwisko}, {self.wiek} lat, oceny: {self.oceny}"

# %%
import random

def generujUcznia():
    imiona = ["Jan", "Anna", "Piotr", "Kasia", "Michał"]
    nazwiska = ["Kowalski", "Nowak", "Wiśniewski", "Wójcik", "Kowalczyk"]

    wiek = random.randint(6, 19)
    oceny = [random.randint(2, 5) for _ in range(5)]

    uczen = Uczen()
    uczen.imie = random.choice(imiona)
    uczen.nazwisko = random.choice(nazwiska)
    uczen.wiek = wiek
    uczen.oceny = oceny

    return uczen

# %%
uczniowie_klasa_1A = []

for _ in range(10):
    uczen = generujUcznia()
    uczniowie_klasa_1A.append(uczen)

print(f"Ilość uczniów w klasie 1A: {len(uczniowie_klasa_1A)}")
print(f"Uczniowie klasy 1A: {uczniowie_klasa_1A}")
# Out:
# Ilość uczniów w klasie 1A: 10
# Uczniowie klasy 1A: [<__main__.Uczen object at 0x000001A0F3657CB0>, <__main__.Uczen object at 0x000001A0F3606E90>, <__main__.Uczen object at 0x000001A0F3607110>, <__main__.Uczen object at 0x000001A0F37F03E0>, <__main__.Uczen object at 0x000001A0F37F0180>, <__main__.Uczen object at 0x000001A0F37D5D90>, <__main__.Uczen object at 0x000001A0F37A9480>, <__main__.Uczen object at 0x000001A0F37A9590>, <__main__.Uczen object at 0x000001A0F35CF650>, <__main__.Uczen object at 0x000001A0F35CF750>]

# %%
print("Informacje o uczniach klasy 1A:")
for uczen in uczniowie_klasa_1A:
    print(uczen.info())
# Out:
# Informacje o uczniach klasy 1A:
# Anna Nowak, 9 lat, oceny: [3, 2, 5, 4, 5]
# Kasia Nowak, 9 lat, oceny: [3, 2, 4, 3, 4]
# Piotr Wiśniewski, 15 lat, oceny: [3, 4, 2, 4, 2]
# Piotr Kowalczyk, 12 lat, oceny: [5, 2, 4, 5, 2]
# Kasia Wiśniewski, 15 lat, oceny: [5, 3, 2, 3, 3]
# Piotr Nowak, 7 lat, oceny: [3, 4, 4, 5, 4]
# Anna Kowalski, 9 lat, oceny: [4, 3, 3, 2, 2]
# Kasia Wójcik, 12 lat, oceny: [2, 4, 4, 2, 3]
# Piotr Nowak, 11 lat, oceny: [5, 3, 2, 2, 2]
# Jan Nowak, 15 lat, oceny: [2, 5, 5, 4, 5]

# %%
for uczen in uczniowie_klasa_1A:
    if uczen.wiek >= 18:
        print(f"{uczen.imie} ma {uczen.wiek} lat, czyli jest pełnoletni")
    else:
        print(f"{uczen.imie} ma {uczen.wiek} lat, czyli nie jest pełnoletni")
# Out:
# Anna ma 9 lat, czyli nie jest pełnoletni
# Kasia ma 9 lat, czyli nie jest pełnoletni
# Piotr ma 15 lat, czyli nie jest pełnoletni
# Piotr ma 12 lat, czyli nie jest pełnoletni
# Kasia ma 15 lat, czyli nie jest pełnoletni
# Piotr ma 7 lat, czyli nie jest pełnoletni
# Anna ma 9 lat, czyli nie jest pełnoletni
# Kasia ma 12 lat, czyli nie jest pełnoletni
# Piotr ma 11 lat, czyli nie jest pełnoletni
# Jan ma 15 lat, czyli nie jest pełnoletni
